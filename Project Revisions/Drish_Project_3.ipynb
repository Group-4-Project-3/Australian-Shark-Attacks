# %%
# Dependencies
import pandas as pd
from pathlib import Path
from dash import Dash, html, dash_table, dcc, Input, Output
import plotly.express as px

# %%
# Upload data
df = "Clean_Australian_Shark_Attacks.csv"
df

clean_df = pd.read_csv(df, encoding = "CP1252")
clean_df
# Out:
#       Unnamed: 0  Incident.year Victim.injury State      Latitude  \
# 0              0           1791         fatal   NSW  -33.86666667
# 1              1           1803       injured    WA  -25.83333333
# 2              2           1807       injured   NSW  -33.86666667
# 3              3           1820         fatal   TAS         -42.8
# 4              4           1825       injured   NSW        -33.85
# ...          ...            ...           ...   ...           ...
# 1223        1223           2023       injured   QLD     -14.06549
# 1224        1224           2023       injured    WA     -30.81556
# 1225        1225           2023       injured   NSW      -31.9694
# 1226        1226           2023         fatal    SA    -34.679356
# 1227        1227           2024       injured    SA      -34.3333
#
#         Longitude    Shark.common.name     Shark.scientific.name  \
# 0           151.2          white shark  Carcharodon carchariasÂ
# 1     113.8833333          tiger shark       Galeocerdo cuvierÂ
# 2           151.2           bull shark       Carcharhinus leucas
# 3     147.5333333              unknown                   unknown
# 4     151.2166667           bull shark       Carcharhinus leucas
# ...           ...                  ...                       ...
# 1223    144.26335              unknown                   unknown
# 1224    115.19234  bronze whaler shark   Carcharhinus brachyurus
# 1225  152.5863946              unknown                   unknown
# 1226  137.684906.          white shark    Carcharodon carcharias
# 1227    135.7500.              unknown                   unknown
#
#      Provoked/unprovoked      Site.category  Incident.month
# 0             unprovoked            coastal               1
# 1             unprovoked            coastal               3
# 2             unprovoked    estuary/harbour               1
# 3               provoked            coastal               1
# 4             unprovoked    estuary/harbour               1
# ...                  ...                ...             ...
# 1223            provoked            coastal              11
# 1224          unprovoked  island open ocean              12
# 1225          unprovoked            coastal              12
# 1226          unprovoked            coastal              12
# 1227          unprovoked            coastal               1
#
# [1228 rows x 11 columns]

# %%
# Checking the number of records.
# total_records = len(clean_df['Unnamed: 0'].unique())
# total_records

# %%
# select my chosen columns focusing on shark types based on state
reduced_df = clean_df.loc[:, ["Shark.common.name", "State"]]
reduced_df
# Out:
#         Shark.common.name State
# 0             white shark   NSW
# 1             tiger shark    WA
# 2              bull shark   NSW
# 3                 unknown   TAS
# 4              bull shark   NSW
# ...                   ...   ...
# 1223              unknown   QLD
# 1224  bronze whaler shark    WA
# 1225              unknown   NSW
# 1226          white shark    SA
# 1227              unknown    SA
#
# [1228 rows x 2 columns]

# %%
# an overall total count by shark common name
total_name = reduced_df['Shark.common.name'].value_counts()
total_name
# Out:
# Shark.common.name
# white shark                  372
# tiger shark                  229
# wobbegong                    203
# bull shark                   201
# whaler shark                  75
# unknown                       61
# bronze whaler shark           29
# grey nurse shark               9
# grey reef shark                8
# whitetip reef shark            7
# lemon shark                    6
# dusky shark                    5
# hammerhead shark               5
# blacktip reef shark            4
# galapagos shark                3
# shortfin mako shark            2
# broadnose sevengill shark      2
# dogfish                        1
# school shark                   1
# sevengill shark                1
# silvertip shark                1
# blind shark                    1
# port jackson shark             1
# seven gill shark               1
# Name: count, dtype: int64

# %%
# count by shark name for each state
totals_df = reduced_df[['State', 'Shark.common.name']].value_counts().reset_index(name='count')
totals_df.head(20)
# Out:
#    State Shark.common.name  count
# 0    QLD       tiger shark    179
# 1    NSW       white shark    155
# 2    NSW         wobbegong    107
# 3    NSW        bull shark    101
# 4    QLD        bull shark     79
# 5     WA       white shark     75
# 6     SA       white shark     63
# 7     WA         wobbegong     52
# 8    VIC       white shark     46
# 9    QLD      whaler shark     28
# 10   QLD           unknown     28
# 11    WA       tiger shark     26
# 12   NSW      whaler shark     26
# 13   TAS       white shark     23
# 14   QLD         wobbegong     22
# 15    WA        bull shark     18
# 16   NSW           unknown     15
# 17   NSW       tiger shark     15
# 18    WA      whaler shark     14
# 19    SA         wobbegong     11

# %%
totals_df.groupby(['State']).value_counts().head(20)
# Out:
# State  Shark.common.name    count
# NSW    blind shark          1        1
#        bronze whaler shark  11       1
#        bull shark           101      1
#        dogfish              1        1
#        dusky shark          4        1
#        galapagos shark      3        1
#        grey nurse shark     7        1
#        tiger shark          15       1
#        unknown              15       1
#        whaler shark         26       1
#        white shark          155      1
#        wobbegong            107      1
# NT     whaler shark         4        1
#        bull shark           3        1
#        tiger shark          9        1
#        unknown              1        1
#        whitetip reef shark  1        1
#        wobbegong            1        1
# QLD    wobbegong            22       1
#        blacktip reef shark  2        1
# Name: count, dtype: int64

# %%
dff = totals_df
dff
# Out:
#    State          Shark.common.name  count
# 0    QLD                tiger shark    179
# 1    NSW                white shark    155
# 2    NSW                  wobbegong    107
# 3    NSW                 bull shark    101
# 4    QLD                 bull shark     79
# ..   ...                        ...    ...
# 58    NT                  wobbegong      1
# 59    NT        whitetip reef shark      1
# 60    NT                    unknown      1
# 61   NSW                    dogfish      1
# 62    SA  broadnose sevengill shark      1
#
# [63 rows x 3 columns]

# %%
# Get unique states and shark common names for dropdown options
states = dff['State'].unique()
names = dff['Shark.common.name'].unique()

# %%
# Initialize the app
app = Dash(__name__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Initialize the app
# ----> 2 app = Dash(__name__)
#
# NameError: name 'Dash' is not defined

# %%
app.layout = html.Div([
    html.H1("Shark Attack Counts by Common Name and State"),
# Dropdown menu for selecting states
    dcc.Dropdown(
        id='state-dropdown',
        options=[{'label': state, 'value': state} for state in states],
        value='NSW',  # Default value
        multi=False,  # Allow single selection
        style={'width': '50%'}
    ),
    # Graph component for displaying the bar chart
    dcc.Graph(id='bar-chart')
])
    
# Define callback to update the bar chart based on dropdown selection
@app.callback(
    Output('bar-chart', 'figure'),
    [Input('state-dropdown', 'value')]
)

def update_bar_chart(selected_state):
    filtered_dff = dff[dff['State'] == selected_state]
    fig = px.bar(filtered_dff, x='Shark.common.name', y='count', color='Shark.common.name',
                 labels={'count': 'Number of Attacks', 'Shark.common.name': 'Shark Common Name'})
    fig.update_layout(title=f'Shark Attack Counts by name in {selected_state}')
    return fig
    
    
        
# run the app
if __name__ == "__main__":
    app.run_server(debug=True, port=2226)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 32
#      30 # run the app
#      31 if __name__ == "__main__":
# ---> 32     app.run_server(debug=True, port=2224)
#
# File ~\anaconda3\Lib\site-packages\dash\dash.py:2223, in Dash.run_server(self, *args, **kwargs)
#    2217 def run_server(self, *args, **kwargs):
#    2218     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2219     future version. We recommend using `app.run` instead.
#    2220
#    2221     See `app.run` for usage information.
#    2222     """
# -> 2223     self.run(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\dash\dash.py:2114, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2111             extra_files.append(path)
#    2113 if jupyter_dash.active:
# -> 2114     jupyter_dash.run_app(
#    2115         self,
#    2116         mode=jupyter_mode,
#    2117         width=jupyter_width,
#    2118         height=jupyter_height,
#    2119         host=host,
#    2120         port=port,
#    2121         server_url=jupyter_server_url,
#    2122     )
#    2123 else:
#    2124     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\anaconda3\Lib\site-packages\dash\_jupyter.py:404, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     402     display(HTML(msg))
#     403 else:
# --> 404     raise final_error
#
# File ~\anaconda3\Lib\site-packages\dash\_jupyter.py:391, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     388         raise err
#     390 try:
# --> 391     wait_for_app()
#     393     if self.in_colab:
#     394         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\anaconda3\Lib\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\anaconda3\Lib\site-packages\retrying.py:266, in Retrying.call(self, fn, *args, **kwargs)
#     263 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     264     if not self._wrap_exception and attempt.has_exception:
#     265         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266         raise attempt.get()
#     267     else:
#     268         raise RetryError(attempt)
#
# File ~\anaconda3\Lib\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File ~\anaconda3\Lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File ~\anaconda3\Lib\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File ~\anaconda3\Lib\site-packages\dash\_jupyter.py:382, in JupyterDash.run_app.<locals>.wait_for_app()
#     380     if res != "Alive":
#     381         url = f"http://{host}:{port}"
# --> 382         raise OSError(
#     383             f"Address '{url}' already in use.\n"
#     384             "    Try passing a different port to run_server."
#     385         )
#     386 except requests.ConnectionError as err:
#     387     _get_error()
#
# OSError: Address 'http://127.0.0.1:2224' already in use.
#     Try passing a different port to run_server.
